# %% [raw]
# ---
# title: "Análisis de la variación en la calidad del aire y sus efectos sobre la salud en Estados Unidos"
# subtitle: "Proyecto de Métodos Numéricos"
#
# author:
#   - Justin Guevara
#   - Derek Cahuate
#   - Elizabeth Lopez
#
# date: today
#
# course: "Métodos Numéricos"
#
# bibliography: inFiles/References/references.bib
#
# format:
#   pdf:
#     template: main.tex
#     cite-method: biblatex
# ---

# %% [markdown]
# # OBJETIVOS
#
# # MARCO TEÓRICO
#
# # PRERREQUISITOS
#
# # DESARROLLO
#
# # CONCLUSIONES
#
# # RECOMENDACIONES
#
# # REFERENCIAS
